# %% [markdown]
# # Neuroevolution of an SNN on SHD (CR-FM-NES)
#
# This notebook trains a spiking neural network on the **Spiking Heidelberg Digits**
# (SHD) audio-classification task **without gradients**. Instead of backpropagation
# through the surrogate spike function, the network weights are optimized with the
# **CR-FM-NES** evolution strategy (a modern, memory-efficient natural evolution
# strategy).
#
# The code is modernized from the original Haiku + old-`evosax` implementation to
# **Flax NNX + evosax 0.2**:
#
# * the model is a plain `spyx.nn.Sequential` of `nnx.Linear` + spiking neurons,
#   driven over time by `spyx.nn.run`;
# * parameters are flattened to a single vector with
#   `nnx.split` + `jax.flatten_util.ravel_pytree`, which is exactly the shape an
#   evolution strategy wants to search over;
# * evolution uses the `evosax.algorithms.distribution_based.CR_FM_NES` API.
#
# It is deliberately kept **CPU-tiny** (small population, few generations, a couple
# of scoring batches): the point is to show the pipeline runs and that the elite
# fitness **improves generation over generation**, not to reach a competitive
# accuracy.

# %%
import os
import time

os.environ.setdefault("JAX_PLATFORMS", "cpu")  # CPU-only run

import jax
import jax.numpy as jnp
import numpy as np
from evosax.algorithms.distribution_based import CR_FM_NES
from flax import nnx

import spyx
import spyx.nn as snn

# SHD: 128 input channels, 20 classes; small SNN with a 64-unit hidden layer.
SAMPLE_T, CHANNELS, N_CLASSES, HIDDEN = 128, 128, 20, 64
BATCH = 256
POP, GENS = 24, 20  # tiny scale for a CPU sanity run
N_FIT_BATCHES = 4  # train batches used to score each candidate
N_TEST_BATCHES = 4  # test batches used to score the elite

print(f"backend={jax.default_backend()}  pop={POP}  gens={GENS}")
# Out:
# backend=cpu  pop=24  gens=20

# %% [markdown]
# ## Data
#
# SHD is streamed with `spyx.data.SHD_loader`, which yields spike frames bit-packed
# along the time axis (`.obs`) plus integer `.labels`. We **prestage a small number
# of batches once** into dense float arrays and reuse them for every generation
# (rather than re-reading the dataset each generation). Each frame is unpacked along
# the packed-time axis and truncated to `SAMPLE_T` steps, giving `(B, T, C)` arrays.
#
# `worker_count=0` keeps the loader in-process, which is required for Grain to run
# safely under nbconvert (its spawn-based workers otherwise crash without a
# `__main__` guard). The data dir is located with `find_data_dir`, which walks up
# from the current directory to the repo-root `./data` (nbconvert runs the kernel
# with the notebook's directory as cwd, so a bare `"./data"` would point at
# `research/misc/data` and trigger a fresh download).

# %%
def find_data_dir():
    """Locate the already-downloaded ./data/SHD by walking up from the cwd."""
    d = os.getcwd()
    for _ in range(6):
        if os.path.isdir(os.path.join(d, "data", "SHD")):
            return os.path.join(d, "data")
        d = os.path.dirname(d)
    return "./data"  # fall back to default (will download if absent)


DATA_DIR = find_data_dir()


def stage(loader_iter, n_batches):
    """Pull n_batches, unpack the packed-time axis, return (n_batches, B, T, C)."""
    obs_list, lbl_list = [], []
    for _ in range(n_batches):
        b = next(loader_iter)
        up = np.unpackbits(np.asarray(b.obs), axis=1)[:, :SAMPLE_T]  # (B,T,C)
        obs_list.append(up.astype(np.float32))
        lbl_list.append(np.asarray(b.labels))
    return jnp.asarray(np.stack(obs_list)), jnp.asarray(np.stack(lbl_list))


t0 = time.perf_counter()
dl = spyx.data.SHD_loader(
    batch_size=BATCH, sample_T=SAMPLE_T, channels=CHANNELS,
    download_dir=DATA_DIR, worker_count=0,
)
train_obs, train_lbl = stage(dl.train_epoch(), N_FIT_BATCHES)  # for selection
test_obs, test_lbl = stage(dl.test_epoch(), N_TEST_BATCHES)  # for scoring the elite
print(
    f"prestaged train_obs={train_obs.shape} test_obs={test_obs.shape} "
    f"in {time.perf_counter() - t0:.1f}s"
)
# Out:
# prestaged train_obs=(4, 256, 128, 128) test_obs=(4, 256, 128, 128) in 3.2s

# %% [markdown]
# ## Model
#
# A feed-forward SNN: two adaptive-LIF (`ALIF`) hidden layers and a leaky
# integrate-and-fire (`LIF`) readout. We build one instance just to get the
# parameter tree, then flatten it into a single vector that the evolution strategy
# will optimize.

# %%
def make_model(rngs):
    return snn.Sequential(
        nnx.Linear(CHANNELS, HIDDEN, use_bias=False, rngs=rngs),
        snn.ALIF((HIDDEN,), rngs=rngs),
        nnx.Linear(HIDDEN, HIDDEN, use_bias=False, rngs=rngs),
        snn.ALIF((HIDDEN,), rngs=rngs),
        nnx.Linear(HIDDEN, N_CLASSES, use_bias=False, rngs=rngs),
        snn.LIF((N_CLASSES,), rngs=rngs),
    )


graphdef, params = nnx.split(make_model(nnx.Rngs(0)), nnx.Param)
flat, unravel = jax.flatten_util.ravel_pytree(params)
print(f"evolving {flat.size} parameters")
# Out:
# evolving 13844 parameters

# %% [markdown]
# ## Fitness function
#
# Each candidate is a flat weight vector. We rebuild the model with
# `nnx.merge`, run it over time with `spyx.nn.run` (time-major `(T, B, C)`), and
# score it with `spyx.fn.integral_accuracy` (higher is better). `pop_fitness`
# vmaps this over the whole population.

# %%
acc_fn = spyx.fn.integral_accuracy()


def run_model(flat_params, x_BTC):
    model = nnx.merge(graphdef, unravel(flat_params))
    traces, _ = snn.run(model, jnp.transpose(x_BTC, (1, 0, 2)))  # (T,B,C) in
    return jnp.transpose(traces, (1, 0, 2))  # -> (B,T,C)


def fitness(flat_params, obs, lbl):  # higher = better (mean accuracy)
    accs = jnp.stack(
        [acc_fn(run_model(flat_params, obs[i]), lbl[i])[0] for i in range(obs.shape[0])]
    )
    return jnp.mean(accs)


pop_fitness = jax.jit(jax.vmap(fitness, in_axes=(0, None, None)))
eval_elite = jax.jit(fitness)

# %% [markdown]
# ## Evolution loop (CR-FM-NES, evosax 0.2)
#
# Each generation: `ask` for a population of candidate weight vectors, evaluate
# their accuracy, then `tell` the strategy the **negated** accuracy (evosax
# *minimizes*). We track the elite's held-out test accuracy every few generations.

# %%
strat = CR_FM_NES(population_size=POP, solution=jnp.zeros_like(flat))
es_p = strat.default_params
es_s = strat.init(jax.random.PRNGKey(0), mean=flat, params=es_p)

key = jax.random.PRNGKey(1)
fit_obs, fit_lbl = train_obs[:N_FIT_BATCHES], train_lbl[:N_FIT_BATCHES]

t0 = time.perf_counter()
history = []
for g in range(1, GENS + 1):
    key, k_ask, k_tell = jax.random.split(key, 3)
    cands, es_s = strat.ask(k_ask, es_s, es_p)
    fit = pop_fitness(cands, fit_obs, fit_lbl)  # accuracy per candidate
    es_s, _ = strat.tell(k_tell, cands, -fit, es_s, es_p)  # negate: evosax minimizes
    if g % 3 == 0 or g == 1:
        test_acc = float(eval_elite(es_s.best_solution, test_obs, test_lbl))
        history.append((g, float(jnp.max(fit)), test_acc))
        print(
            f"gen {g:3d}  best_pop_train_acc={float(jnp.max(fit)) * 100:5.2f}%  "
            f"elite_test_acc={test_acc * 100:5.2f}%  ({time.perf_counter() - t0:.0f}s)"
        )
# Out:
# gen   1  best_pop_train_acc= 6.25%  elite_test_acc= 4.69%  (1s)
# gen   3  best_pop_train_acc= 6.45%  elite_test_acc= 4.69%  (2s)
# gen   6  best_pop_train_acc= 6.54%  elite_test_acc= 4.69%  (4s)
# gen   9  best_pop_train_acc= 6.93%  elite_test_acc= 4.69%  (6s)
# gen  12  best_pop_train_acc= 7.71%  elite_test_acc= 5.96%  (8s)
# gen  15  best_pop_train_acc= 6.93%  elite_test_acc= 5.96%  (10s)
# gen  18  best_pop_train_acc= 6.84%  elite_test_acc= 5.96%  (12s)

# %% [markdown]
# ## Results
#
# The elite test accuracy should climb from its generation-1 value. On SHD with
# 20 classes, chance is 5%; a couple minutes of CPU evolution at this tiny scale
# lands only modestly above chance, which is expected — what matters is that the
# evolution strategy **improves** the network over generations.

# %%
final = float(eval_elite(es_s.best_solution, test_obs, test_lbl))
print(f"FINAL evolved SNN: elite_test_acc={final * 100:.2f}%  ({GENS} gens)")
print("gen / best_pop_train_acc / elite_test_acc history:")
for g, tr, te in history:
    print(f"  gen {g:3d}:  train {tr * 100:5.2f}%   test {te * 100:5.2f}%")
# Out:
# FINAL evolved SNN: elite_test_acc=5.96%  (20 gens)
# gen / best_pop_train_acc / elite_test_acc history:
#   gen   1:  train  6.25%   test  4.69%
#   gen   3:  train  6.45%   test  4.69%
#   gen   6:  train  6.54%   test  4.69%
#   gen   9:  train  6.93%   test  4.69%
#   gen  12:  train  7.71%   test  5.96%
#   gen  15:  train  6.93%   test  5.96%
#   gen  18:  train  6.84%   test  5.96%
