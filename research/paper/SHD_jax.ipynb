# %%
import haiku as hk
import jax
import jax.numpy as jnp
import numpy as np
import optax
from jax_tqdm import scan_tqdm

import spyx

# %%
x = jnp.array([1,2,3])
x.devices()
# Out:
# {cuda(id=0)}

# %% [markdown]
# ### SHD Dataloading

# %%
from collections import namedtuple

import tonic
from tonic import datasets, transforms
from torch.utils.data import DataLoader

State = namedtuple("State", "obs labels")

# %%
class _SHD2Raster():
    """ 
    Tool for rastering SHD samples into frames. Packs bits along the temporal axis for memory efficiency. This means
        that the used will have to apply jnp.unpackbits(events, axis=<time axis>) prior to feeding the data to the network.
    """

    def __init__(self, encoding_dim, sample_T = 100):
        self.encoding_dim = encoding_dim
        self.sample_T = sample_T
        
    def __call__(self, events):
        # tensor has dimensions (time_steps, encoding_dim)
        tensor = np.zeros((events["t"].max()+1, self.encoding_dim), dtype=int)
        np.add.at(tensor, (events["t"], events["x"]), 1)
        #return tensor[:self.sample_T,:]
        tensor = tensor[:self.sample_T,:]
        tensor = np.minimum(tensor, 1)
        tensor = np.packbits(tensor, axis=0)
        return tensor

# %%
sample_T = 256
shd_timestep = 1e-6
shd_channels = 700
net_channels = 128
net_dt = 1/sample_T

obs_shape = tuple([net_channels,])
act_shape = tuple([20,])

transform = transforms.Compose([
    transforms.Downsample(
        time_factor=shd_timestep / net_dt,
        spatial_factor=net_channels / shd_channels
    ),
    _SHD2Raster(net_channels, sample_T=sample_T)
])

train_dataset = datasets.SHD("./data", train=True, transform=transform)
test_dataset = datasets.SHD("./data", train=False, transform=transform)

# %%
train_dl = iter(DataLoader(train_dataset, batch_size=len(train_dataset),
                          collate_fn=tonic.collation.PadTensors(batch_first=True), drop_last=True, shuffle=False))
        
x_train, y_train = next(train_dl)

# %%
test_dl = iter(DataLoader(test_dataset, batch_size=len(test_dataset),
                          collate_fn=tonic.collation.PadTensors(batch_first=True), drop_last=True, shuffle=False))
        
x_test, y_test = next(test_dl)

# %%
print(type(x_train))
print(x_train.shape)
# Out:
# <class 'torch.Tensor'>
# torch.Size([8156, 32, 128])

# %%
x_train = jnp.array(x_train, dtype=jnp.uint8)
y_train = jnp.array(y_train, dtype=jnp.uint8)

#x_test = jnp.array(x_test, dtype=jnp.uint8)
#y_test = jnp.array(y_test, dtype=jnp.uint8)

# %%
def _shuffle(dataset, shuffle_rng, batch_size):
    x, y = dataset

    full_batches = y.shape[0] // batch_size

    indices = jax.random.permutation(shuffle_rng, y.shape[0])[:full_batches*batch_size]
    obs, labels = x[indices], y[indices]

    obs = jnp.reshape(obs, (-1, batch_size) + obs.shape[1:])
    labels = jnp.reshape(labels, (-1, batch_size)) # should make batch size a global

    return obs, labels

shuffle = jax.jit(_shuffle, static_argnums=2)

# %% [markdown]
# ### Spyx SHD

# %%
def build_snn(hidden_shape, batch_size):

    def shd_snn(x): 
        
        core = hk.DeepRNN([
            hk.Linear(hidden_shape, with_bias=False),
            spyx.nn.LIF((hidden_shape,), activation=spyx.axn.arctan()),
            hk.Linear(hidden_shape, with_bias=False),
            spyx.nn.LIF((hidden_shape,), activation=spyx.axn.arctan()),
            hk.Linear(20, with_bias=False),
            spyx.nn.LI((20,))
        ])
        
        # static unroll for maximum performance
        spikes, V = hk.static_unroll(core, x, core.initial_state(x.shape[0]), time_major=False)
        
        return spikes, V
    
    key = jax.random.PRNGKey(0)
    # Since there's nothing stochastic about the network, we can avoid using an RNG as a param!
    sample_x, sample_y = shuffle((x_train,y_train),key, batch_size)
    SNN = hk.without_apply_rng(hk.transform(shd_snn))
    params = SNN.init(rng=key, x=jnp.float32(sample_x[0]))
    
    return SNN, params

# %%
def build_multistep_snn(hidden_shape, batch_size):

    l1 = hk.Linear(hidden_shape, with_bias=False)
    core1 = spyx.nn.LIF((hidden_shape,), activation=spyx.axn.arctan())
    l2 = hk.Linear(hidden_shape, with_bias=False)
    core2 = spyx.nn.LIF((hidden_shape,), activation=spyx.axn.arctan())
    l3 = hk.Linear(20, with_bias=False)
    core3 = spyx.nn.LIF((20,), activation=spyx.axn.arctan())

    def shd_snn(x):
        x = hk.BatchApply(l1)(x)
        x = hk.static_unroll(core1, x, core.initial_state(x.shape[0]))(x)
        x = hk.BatchApply(l2)(x)
        x = hk.static_unroll(core2, x, core.initial_state(x.shape[0]))(x)
        x = hk.BatchApply(l3)(x)
        x = hk.static_unroll(core3, x, core.initial_state(x.shape[0]))(x)

        

        spikes, V = hk.static_unroll(core, x, core.initial_state(x.shape[0]), time_major=False)
        
        return spikes, V
    
    key = jax.random.PRNGKey(0)
    # Since there's nothing stochastic about the network, we can avoid using an RNG as a param!
    sample_x, sample_y = shuffle((x_train,y_train),key, batch_size)
    SNN = hk.without_apply_rng(hk.transform(shd_snn))
    params = SNN.init(rng=key, x=jnp.float32(sample_x[0]))
    
    return SNN, params

# %%
def benchmark(SNN, params, dataset, epochs, batch_size):
        
    opt = optax.adam(learning_rate=5e-4)
    
    # create and initialize the optimizer
    opt_state = opt.init(params)
    grad_params = params

    Loss = spyx.fn.integral_crossentropy()
        
    # define and compile our eval function that computes the loss for our SNN
    @jax.jit
    def net_eval(weights, events, targets):
        readout = SNN.apply(weights, events)
        traces, V_f = readout
        return Loss(traces, targets) # smoothing needs to be more explicit in docs...
        
    # Use JAX to create a function that calculates the loss and the gradient!
    surrogate_grad = jax.value_and_grad(net_eval) 
        
    rng = jax.random.PRNGKey(0)        
    
    # compile the meat of our training loop for speed
    @jax.jit
    def train_step(state, data):
        grad_params, opt_state = state
        events, targets = data
        # events = jnp.swapaxes(events, 0, 1)
        events = jnp.unpackbits(events, axis=1) # decompress temporal axis
        # compute loss and gradient                    # need better augment rng
        loss, grads = surrogate_grad(grad_params, events, targets)
        # generate updates based on the gradients and optimizer
        updates, opt_state = opt.update(grads, opt_state, grad_params)
        # return the updated parameters
        new_state = [optax.apply_updates(grad_params, updates), opt_state]
        return new_state, loss
    
    
    # Here's the start of our training loop!
    @scan_tqdm(epochs)
    def epoch(epoch_state, epoch_num):
        curr_params, curr_opt_state = epoch_state

        shuffle_rng = jax.random.fold_in(rng, epoch_num)
        train_data = shuffle(dataset, shuffle_rng, batch_size)
        
        # train epoch
        end_state, train_loss = jax.lax.scan(
            train_step,# func
            [curr_params, curr_opt_state],# init
            train_data,# xs
        )
                    
        return end_state, jnp.mean(train_loss)
    # end epoch
    
    # epoch loop
    final_state, metrics = jax.lax.scan(
        epoch,
        [grad_params, opt_state], # metric arrays
        jnp.arange(epochs), # 
        epochs # len of loop
    )
    
    final_params, _ = final_state
    
                
    # return our final, optimized network.       
    return final_params, metrics

# %%
from time import time


def run_bench(trials, num_epochs, net_width, batch_size):
    
    SNN, params = build_snn(net_width, batch_size)

    times = []
    for t in range(trials+1):
        print(t, ":", end="")
        start = time()
        benchmark(SNN, params, (x_train,y_train), num_epochs, batch_size)
        times.append(time() - start)
        print(times[t])
    
    print("Mean:", np.mean(times[1:]), "Std. Dev.:", np.std(times[1:]))

# %%
run_bench(5, 100, 128, 256)
# Out:
# 0 :
#   0%|          | 0/100 [00:00<?, ?it/s]
# 100.58096218109131
# 1 :
#   0%|          | 0/100 [00:00<?, ?it/s]
# 103.81011533737183
# 2 :
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_12858/1891944843.py in <module>
# ----> 1 run_bench(5, 100, 128, 256)
#
# /tmp/ipykernel_12858/136898192.py in run_bench(trials, num_epochs, net_width, batch_size)
#       9         print(t, ":", end="")
#      10         start = time()
# ---> 11         benchmark(SNN, params, (x_train,y_train), num_epochs, batch_size)
#      12         times.append(time() - start)
#      13         print(times[t])
#
# /tmp/ipykernel_12858/214335361.py in benchmark(SNN, params, dataset, epochs, batch_size)
#      55
#      56     # epoch loop
# ---> 57     final_state, metrics = jax.lax.scan(
#      58         epoch,
#      59         [grad_params, opt_state], # metric arrays
#
#     [... skipping hidden 1 frame]
#
# ~/.local/lib/python3.10/site-packages/jax/_src/lax/control_flow/loops.py in scan(f, init, xs, length, reverse, unroll)
#     279     in_flat = [*in_state, *in_carry, *in_ext]
#     280     num_carry += len(attrs_tracked)
# --> 281   out = scan_p.bind(*consts, *in_flat,
#     282                     reverse=reverse, length=length, jaxpr=jaxpr,
#     283                     num_consts=len(consts), num_carry=num_carry,
#
# ~/.local/lib/python3.10/site-packages/jax/_src/lax/control_flow/loops.py in scan_bind(*args, **params)
#    1155     _scan_typecheck(True, *in_atoms, **params)
#    1156     core.check_jaxpr(params['jaxpr'].jaxpr)
# -> 1157   return core.AxisPrimitive.bind(scan_p, *args, **params)
#    1158
#    1159 scan_p = core.AxisPrimitive("scan")
#
# ~/.local/lib/python3.10/site-packages/jax/_src/core.py in bind(self, *args, **params)
#    2725     top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2726                  else axis_main.with_cur_sublevel())
# -> 2727     return self.bind_with_trace(top_trace, args, params)
#    2728
#    2729
#
# ~/.local/lib/python3.10/site-packages/jax/_src/core.py in bind_with_trace(self, trace, args, params)
#     421
#     422   def bind_with_trace(self, trace, args, params):
# --> 423     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     424     return map(full_lower, out) if self.multiple_results else full_lower(out)
#     425
#
# ~/.local/lib/python3.10/site-packages/jax/_src/core.py in process_primitive(self, primitive, tracers, params)
#     911
#     912   def process_primitive(self, primitive, tracers, params):
# --> 913     return primitive.impl(*tracers, **params)
#     914
#     915   def process_call(self, primitive, f, tracers, params):
#
# ~/.local/lib/python3.10/site-packages/jax/_src/dispatch.py in apply_primitive(prim, *args, **params)
#      85     prev = lib.jax_jit.swap_thread_local_state_disable_jit(False)
#      86     try:
# ---> 87       outs = fun(*args)
#      88     finally:
#      89       lib.jax_jit.swap_thread_local_state_disable_jit(prev)
#
#     [... skipping hidden 1 frame]
#
# ~/.local/lib/python3.10/site-packages/jax/_src/pjit.py in cache_miss(*args, **kwargs)
#     246   @api_boundary
#     247   def cache_miss(*args, **kwargs):
# --> 248     outs, out_flat, out_tree, args_flat, jaxpr, attrs_tracked = _python_pjit_helper(
#     249         fun, infer_params_fn, *args, **kwargs)
#     250     executable = _read_most_recent_pjit_call_executable(jaxpr)
#
# ~/.local/lib/python3.10/site-packages/jax/_src/pjit.py in _python_pjit_helper(fun, infer_params_fn, *args, **kwargs)
#     141     args_flat = [*init_states, *args_flat]
#     142   try:
# --> 143     out_flat = pjit_p.bind(*args_flat, **params)
#     144   except pxla.DeviceAssignmentMismatchError as e:
#     145     fails, = e.args
#
# ~/.local/lib/python3.10/site-packages/jax/_src/core.py in bind(self, *args, **params)
#    2725     top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2726                  else axis_main.with_cur_sublevel())
# -> 2727     return self.bind_with_trace(top_trace, args, params)
#    2728
#    2729
#
# ~/.local/lib/python3.10/site-packages/jax/_src/core.py in bind_with_trace(self, trace, args, params)
#     421
#     422   def bind_with_trace(self, trace, args, params):
# --> 423     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     424     return map(full_lower, out) if self.multiple_results else full_lower(out)
#     425
#
# ~/.local/lib/python3.10/site-packages/jax/_src/core.py in process_primitive(self, primitive, tracers, params)
#     911
#     912   def process_primitive(self, primitive, tracers, params):
# --> 913     return primitive.impl(*tracers, **params)
#     914
#     915   def process_call(self, primitive, f, tracers, params):
#
# ~/.local/lib/python3.10/site-packages/jax/_src/pjit.py in _pjit_call_impl(jaxpr, in_shardings, out_shardings, resource_env, donated_invars, name, keep_unused, inline, *args)
#    1407       in_shardings, out_shardings, None, None)
#    1408   if xla_extension_version >= 226:
# -> 1409     return xc._xla.pjit(
#    1410         name, f, call_impl_cache_miss, [], [], donated_argnums,
#    1411         tree_util.dispatch_registry,
#
# ~/.local/lib/python3.10/site-packages/jax/_src/pjit.py in call_impl_cache_miss(*args_, **kwargs_)
#    1390                     donated_invars, name, keep_unused, inline):
#    1391   def call_impl_cache_miss(*args_, **kwargs_):
# -> 1392     out_flat, compiled = _pjit_call_impl_python(
#    1393         *args, jaxpr=jaxpr, in_shardings=in_shardings,
#    1394         out_shardings=out_shardings, resource_env=resource_env,
#
# ~/.local/lib/python3.10/site-packages/jax/_src/pjit.py in _pjit_call_impl_python(jaxpr, in_shardings, out_shardings, resource_env, donated_invars, name, keep_unused, inline, *args)
#    1323       resource_env.physical_mesh if resource_env is not None else None)
#    1324
# -> 1325   compiled = _pjit_lower(
#    1326       jaxpr, in_shardings, out_shardings, resource_env,
#    1327       donated_invars, name, keep_unused, inline,
#
# ~/.local/lib/python3.10/site-packages/jax/_src/pjit.py in _pjit_lower(jaxpr, in_shardings, out_shardings, *args, **kwargs)
#    1461   in_shardings = SameDeviceAssignmentTuple(tuple(in_shardings), da)
#    1462   out_shardings = SameDeviceAssignmentTuple(tuple(out_shardings), da)
# -> 1463   return _pjit_lower_cached(jaxpr, in_shardings, out_shardings, *args, **kwargs)
#    1464
#    1465
#
# ~/.local/lib/python3.10/site-packages/jax/_src/pjit.py in _pjit_lower_cached(jaxpr, sdat_in_shardings, sdat_out_shardings, resource_env, donated_invars, name, keep_unused, inline, lowering_parameters, in_layouts, out_layouts)
#    1509       lowering_parameters=lowering_parameters)
#    1510   else:
# -> 1511     return pxla.lower_sharding_computation(
#    1512         jaxpr, api_name, name, in_shardings, out_shardings,
#    1513         tuple(donated_invars), tuple(jaxpr.in_avals),
#
# ~/.local/lib/python3.10/site-packages/jax/_src/profiler.py in wrapper(*args, **kwargs)
#     334   def wrapper(*args, **kwargs):
#     335     with TraceAnnotation(name, **decorator_kwargs):
# --> 336       return func(*args, **kwargs)
#     337     return wrapper
#     338   return wrapper
#
# ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/pxla.py in lower_sharding_computation(closed_jaxpr, api_name, fun_name, in_shardings, out_shardings, donated_invars, global_in_avals, keep_unused, inline, devices_from_context, lowering_parameters, in_layouts, out_layouts)
#    2036
#    2037   (module, keepalive, host_callbacks, unordered_effects, ordered_effects,
# -> 2038    nreps, tuple_args, shape_poly_state) = _cached_lowering_to_hlo(
#    2039        closed_jaxpr, api_name, fun_name, backend, semantic_in_shardings,
#    2040        semantic_out_shardings, in_layouts, out_layouts, len(da_object),
#
# ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/pxla.py in _cached_lowering_to_hlo(closed_jaxpr, api_name, fun_name, backend, semantic_in_shardings, semantic_out_shardings, in_layouts, out_layouts, num_devices, device_assignment, donated_invars, name_stack, all_default_mem_kind, lowering_parameters)
#    1877         "Finished jaxpr to MLIR module conversion {fun_name} in {elapsed_time} sec",
#    1878         fun_name=str(name_stack), event=dispatch.JAXPR_TO_MLIR_MODULE_EVENT):
# -> 1879     lowering_result = mlir.lower_jaxpr_to_module(
#    1880         module_name,
#    1881         closed_jaxpr,
#
# ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/mlir.py in lower_jaxpr_to_module(***failed resolving arguments***)
#     968     attrs["mhlo.num_partitions"] = i32_attr(num_partitions)
#     969     replace_tokens_with_dummy = lowering_parameters.replace_tokens_with_dummy
# --> 970     lower_jaxpr_to_fun(
#     971         ctx, "main", jaxpr, ordered_effects,
#     972         name_stack=name_stack,
#
# ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/mlir.py in lower_jaxpr_to_fun(ctx, name, jaxpr, effects, name_stack, create_tokens, public, replace_tokens_with_dummy, replicated_args, arg_shardings, result_shardings, use_sharding_annotations, input_output_aliases, xla_donated_args, num_output_tokens, api_name, arg_names, result_names, arg_memory_kinds, result_memory_kinds, arg_layouts, result_layouts)
#    1413     callee_name_stack = name_stack.extend(util.wrap_name(name, api_name))
#    1414     consts = [ir_constants(xla.canonicalize_dtype(x)) for x in jaxpr.consts]
# -> 1415     out_vals, tokens_out = jaxpr_subcomp(
#    1416         ctx, jaxpr.jaxpr, callee_name_stack, tokens_in,
#    1417         consts, *args, dim_var_values=dim_var_values)
#
# ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/mlir.py in jaxpr_subcomp(ctx, jaxpr, name_stack, tokens, consts, dim_var_values, *args)
#    1594
#    1595       rule_inputs = map(_unwrap_singleton_ir_values, in_nodes)
# -> 1596       ans = lower_per_platform(rule_ctx, str(eqn.primitive),
#    1597                                platform_rules, default_rule,
#    1598                                eqn.effects,
#
# ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/mlir.py in lower_per_platform(ctx, description, platform_rules, default_rule, effects, *rule_args, **rule_kwargs)
#    1702   # If there is a single rule left just apply the rule, without conditionals.
#    1703   if len(kept_rules) == 1:
# -> 1704    return kept_rules[0](ctx, *rule_args, **rule_kwargs)
#    1705
#    1706   assert len(platforms) > 1 and len(kept_rules) >= 2, (platforms, kept_rules)
#
# ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/mlir.py in f_lowered(ctx, *args, **params)
#    1789       # TODO(frostig,mattjj): check ctx.avals_out against jaxpr avals out?
#    1790
# -> 1791     out, tokens = jaxpr_subcomp(
#    1792         ctx.module_context, jaxpr, ctx.name_stack, ctx.tokens_in,
#    1793         _ir_consts(consts), *map(wrap_singleton_ir_values, args),
#
# ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/mlir.py in jaxpr_subcomp(ctx, jaxpr, name_stack, tokens, consts, dim_var_values, *args)
#    1594
#    1595       rule_inputs = map(_unwrap_singleton_ir_values, in_nodes)
# -> 1596       ans = lower_per_platform(rule_ctx, str(eqn.primitive),
#    1597                                platform_rules, default_rule,
#    1598                                eqn.effects,
#
# ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/mlir.py in lower_per_platform(ctx, description, platform_rules, default_rule, effects, *rule_args, **rule_kwargs)
#    1702   # If there is a single rule left just apply the rule, without conditionals.
#    1703   if len(kept_rules) == 1:
# -> 1704    return kept_rules[0](ctx, *rule_args, **rule_kwargs)
#    1705
#    1706   assert len(platforms) > 1 and len(kept_rules) >= 2, (platforms, kept_rules)
#
# ~/.local/lib/python3.10/site-packages/jax/_src/lax/control_flow/loops.py in _while_lowering(ctx, cond_jaxpr, body_jaxpr, cond_nconsts, body_nconsts, *args)
#    1716     body_consts = [mlir.ir_constants(xla.canonicalize_dtype(x))
#    1717                    for x in body_jaxpr.consts]
# -> 1718     new_z, tokens_out = mlir.jaxpr_subcomp(
#    1719         ctx.module_context, body_jaxpr.jaxpr, body_name_stack,
#    1720         tokens_in, body_consts, *(y + z), dim_var_values=ctx.dim_var_values)
#
# ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/mlir.py in jaxpr_subcomp(ctx, jaxpr, name_stack, tokens, consts, dim_var_values, *args)
#    1594
#    1595       rule_inputs = map(_unwrap_singleton_ir_values, in_nodes)
# -> 1596       ans = lower_per_platform(rule_ctx, str(eqn.primitive),
#    1597                                platform_rules, default_rule,
#    1598                                eqn.effects,
#
# ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/mlir.py in lower_per_platform(ctx, description, platform_rules, default_rule, effects, *rule_args, **rule_kwargs)
#    1702   # If there is a single rule left just apply the rule, without conditionals.
#    1703   if len(kept_rules) == 1:
# -> 1704    return kept_rules[0](ctx, *rule_args, **rule_kwargs)
#    1705
#    1706   assert len(platforms) > 1 and len(kept_rules) >= 2, (platforms, kept_rules)
#
# ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/mlir.py in f_lowered(ctx, *args, **params)
#    1789       # TODO(frostig,mattjj): check ctx.avals_out against jaxpr avals out?
#    1790
# -> 1791     out, tokens = jaxpr_subcomp(
#    1792         ctx.module_context, jaxpr, ctx.name_stack, ctx.tokens_in,
#    1793         _ir_consts(consts), *map(wrap_singleton_ir_values, args),
#
# ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/mlir.py in jaxpr_subcomp(ctx, jaxpr, name_stack, tokens, consts, dim_var_values, *args)
#    1594
#    1595       rule_inputs = map(_unwrap_singleton_ir_values, in_nodes)
# -> 1596       ans = lower_per_platform(rule_ctx, str(eqn.primitive),
#    1597                                platform_rules, default_rule,
#    1598                                eqn.effects,
#
# ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/mlir.py in lower_per_platform(ctx, description, platform_rules, default_rule, effects, *rule_args, **rule_kwargs)
#    1702   # If there is a single rule left just apply the rule, without conditionals.
#    1703   if len(kept_rules) == 1:
# -> 1704    return kept_rules[0](ctx, *rule_args, **rule_kwargs)
#    1705
#    1706   assert len(platforms) > 1 and len(kept_rules) >= 2, (platforms, kept_rules)
#
# ~/.local/lib/python3.10/site-packages/jax/_src/lax/control_flow/loops.py in _while_lowering(ctx, cond_jaxpr, body_jaxpr, cond_nconsts, body_nconsts, *args)
#    1716     body_consts = [mlir.ir_constants(xla.canonicalize_dtype(x))
#    1717                    for x in body_jaxpr.consts]
# -> 1718     new_z, tokens_out = mlir.jaxpr_subcomp(
#    1719         ctx.module_context, body_jaxpr.jaxpr, body_name_stack,
#    1720         tokens_in, body_consts, *(y + z), dim_var_values=ctx.dim_var_values)
#
# ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/mlir.py in jaxpr_subcomp(ctx, jaxpr, name_stack, tokens, consts, dim_var_values, *args)
#    1594
#    1595       rule_inputs = map(_unwrap_singleton_ir_values, in_nodes)
# -> 1596       ans = lower_per_platform(rule_ctx, str(eqn.primitive),
#    1597                                platform_rules, default_rule,
#    1598                                eqn.effects,
#
# ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/mlir.py in lower_per_platform(ctx, description, platform_rules, default_rule, effects, *rule_args, **rule_kwargs)
#    1702   # If there is a single rule left just apply the rule, without conditionals.
#    1703   if len(kept_rules) == 1:
# -> 1704    return kept_rules[0](ctx, *rule_args, **rule_kwargs)
#    1705
#    1706   assert len(platforms) > 1 and len(kept_rules) >= 2, (platforms, kept_rules)
#
# ~/.local/lib/python3.10/site-packages/jax/_src/pjit.py in _pjit_lowering(ctx, name, jaxpr, in_shardings, out_shardings, resource_env, donated_invars, keep_unused, inline, *args)
#    1618   flat_output_types = flatten(output_types)
#    1619
# -> 1620   func = _pjit_cached_lower_jaxpr_to_fun(
#    1621       ctx, name, jaxpr, tuple(effects), in_shardings,
#    1622       out_shardings, api_name=('jit' if resource_env is None else 'pjit'))
#
# ~/.local/lib/python3.10/site-packages/jax/_src/pjit.py in _pjit_cached_lower_jaxpr_to_fun(ctx, name, jaxpr, effects, in_shardings, out_shardings, api_name)
#    1602     # inputs or outputs because they are lost during MLIR->HLO conversion.
#    1603     # using_sharding_annotation=False means we add an identity operation instead.
# -> 1604     func = mlir.lower_jaxpr_to_fun(
#    1605         mod_ctx, name, jaxpr, effects, ctx.name_stack,
#    1606         arg_shardings=arg_shardings, result_shardings=result_shardings,
#
# ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/mlir.py in lower_jaxpr_to_fun(ctx, name, jaxpr, effects, name_stack, create_tokens, public, replace_tokens_with_dummy, replicated_args, arg_shardings, result_shardings, use_sharding_annotations, input_output_aliases, xla_donated_args, num_output_tokens, api_name, arg_names, result_names, arg_memory_kinds, result_memory_kinds, arg_layouts, result_layouts)
#    1413     callee_name_stack = name_stack.extend(util.wrap_name(name, api_name))
#    1414     consts = [ir_constants(xla.canonicalize_dtype(x)) for x in jaxpr.consts]
# -> 1415     out_vals, tokens_out = jaxpr_subcomp(
#    1416         ctx, jaxpr.jaxpr, callee_name_stack, tokens_in,
#    1417         consts, *args, dim_var_values=dim_var_values)
#
# ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/mlir.py in jaxpr_subcomp(ctx, jaxpr, name_stack, tokens, consts, dim_var_values, *args)
#    1594
#    1595       rule_inputs = map(_unwrap_singleton_ir_values, in_nodes)
# -> 1596       ans = lower_per_platform(rule_ctx, str(eqn.primitive),
#    1597                                platform_rules, default_rule,
#    1598                                eqn.effects,
#
# ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/mlir.py in lower_per_platform(ctx, description, platform_rules, default_rule, effects, *rule_args, **rule_kwargs)
#    1702   # If there is a single rule left just apply the rule, without conditionals.
#    1703   if len(kept_rules) == 1:
# -> 1704    return kept_rules[0](ctx, *rule_args, **rule_kwargs)
#    1705
#    1706   assert len(platforms) > 1 and len(kept_rules) >= 2, (platforms, kept_rules)
#
# ~/.local/lib/python3.10/site-packages/jax/_src/pjit.py in _pjit_lowering(ctx, name, jaxpr, in_shardings, out_shardings, resource_env, donated_invars, keep_unused, inline, *args)
#    1618   flat_output_types = flatten(output_types)
#    1619
# -> 1620   func = _pjit_cached_lower_jaxpr_to_fun(
#    1621       ctx, name, jaxpr, tuple(effects), in_shardings,
#    1622       out_shardings, api_name=('jit' if resource_env is None else 'pjit'))
#
# ~/.local/lib/python3.10/site-packages/jax/_src/pjit.py in _pjit_cached_lower_jaxpr_to_fun(ctx, name, jaxpr, effects, in_shardings, out_shardings, api_name)
#    1602     # inputs or outputs because they are lost during MLIR->HLO conversion.
#    1603     # using_sharding_annotation=False means we add an identity operation instead.
# -> 1604     func = mlir.lower_jaxpr_to_fun(
#    1605         mod_ctx, name, jaxpr, effects, ctx.name_stack,
#    1606         arg_shardings=arg_shardings, result_shardings=result_shardings,
#
# ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/mlir.py in lower_jaxpr_to_fun(ctx, name, jaxpr, effects, name_stack, create_tokens, public, replace_tokens_with_dummy, replicated_args, arg_shardings, result_shardings, use_sharding_annotations, input_output_aliases, xla_donated_args, num_output_tokens, api_name, arg_names, result_names, arg_memory_kinds, result_memory_kinds, arg_layouts, result_layouts)
#    1413     callee_name_stack = name_stack.extend(util.wrap_name(name, api_name))
#    1414     consts = [ir_constants(xla.canonicalize_dtype(x)) for x in jaxpr.consts]
# -> 1415     out_vals, tokens_out = jaxpr_subcomp(
#    1416         ctx, jaxpr.jaxpr, callee_name_stack, tokens_in,
#    1417         consts, *args, dim_var_values=dim_var_values)
#
# ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/mlir.py in jaxpr_subcomp(ctx, jaxpr, name_stack, tokens, consts, dim_var_values, *args)
#    1594
#    1595       rule_inputs = map(_unwrap_singleton_ir_values, in_nodes)
# -> 1596       ans = lower_per_platform(rule_ctx, str(eqn.primitive),
#    1597                                platform_rules, default_rule,
#    1598                                eqn.effects,
#
# ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/mlir.py in lower_per_platform(ctx, description, platform_rules, default_rule, effects, *rule_args, **rule_kwargs)
#    1702   # If there is a single rule left just apply the rule, without conditionals.
#    1703   if len(kept_rules) == 1:
# -> 1704    return kept_rules[0](ctx, *rule_args, **rule_kwargs)
#    1705
#    1706   assert len(platforms) > 1 and len(kept_rules) >= 2, (platforms, kept_rules)
#
# ~/.local/lib/python3.10/site-packages/jax/_src/pjit.py in _pjit_lowering(ctx, name, jaxpr, in_shardings, out_shardings, resource_env, donated_invars, keep_unused, inline, *args)
#    1614                    keep_unused, inline):
#    1615   effects = list(ctx.tokens_in.effects())
# -> 1616   output_types = map(mlir.aval_to_ir_types, ctx.avals_out)
#    1617   output_types = [mlir.token_type()] * len(effects) + output_types
#    1618   flat_output_types = flatten(output_types)
#
# ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/mlir.py in aval_to_ir_types(aval)
#     205   function returns multiple types."""
#     206   try:
# --> 207     return ir_type_handlers[type(aval)](aval)
#     208   except KeyError as err:
#     209     raise TypeError(f"No ir_type_handler for aval type: {type(aval)}") from err
#
# ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/mlir.py in _array_ir_types(aval)
#     189   if not core.is_constant_shape(aval.shape):
#     190     return _dynamic_array_ir_types(aval)  # type: ignore
# --> 191   return (ir.RankedTensorType.get(aval.shape, dtype_to_ir_type(aval.dtype)),)
#     192
#     193 def _dynamic_array_ir_types(aval: core.ShapedArray) -> Sequence[ir.Type]:
#
# ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/mlir.py in dtype_to_ir_type(dtype)
#     182     raise TypeError(
#     183         f"No dtype_to_ir_type handler for dtype: {dtype}") from err
# --> 184   return ir_type_factory()
#     185
#     186 def _array_ir_types(aval: core.ShapedArray | core.DShapedArray
#
# KeyboardInterrupt:

# %%
run_bench(5, 100, 128, 128)
# Out:
# 0 :
#   0%|          | 0/100 [00:00<?, ?it/s]
# 46.61739468574524
# 1 :
#   0%|          | 0/100 [00:00<?, ?it/s]
# 46.04706287384033
# 2 :
#   0%|          | 0/100 [00:00<?, ?it/s]
# 45.88801288604736
# 3 :
#   0%|          | 0/100 [00:00<?, ?it/s]
# 46.05511808395386
# 4 :
#   0%|          | 0/100 [00:00<?, ?it/s]
# 45.91830658912659
# 5 :
#   0%|          | 0/100 [00:00<?, ?it/s]
# 45.91482067108154
# Mean: 45.96466422080994 Std. Dev.: 0.07138665976859078

# %%
run_bench(1, 100, 128, 64)
# Out:
# 0 :
#   0%|          | 0/100 [00:00<?, ?it/s]
# 113.09277486801147
# 1 :
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
run_bench(5, 100, 512, 64)
# Out:
# 0 :
#   0%|          | 0/100 [00:00<?, ?it/s]
# 97.50239658355713
# 1 :
#   0%|          | 0/100 [00:00<?, ?it/s]
# 98.45136499404907
# 2 :
#   0%|          | 0/100 [00:00<?, ?it/s]
# 99.08661842346191
# 3 :
#   0%|          | 0/100 [00:00<?, ?it/s]
# 98.69157314300537
# 4 :
#   0%|          | 0/100 [00:00<?, ?it/s]
# 98.5738685131073
# 5 :
#   0%|          | 0/100 [00:00<?, ?it/s]
# 98.65601754188538
# Mean: 98.69188852310181 Std. Dev.: 0.213952710561666

# %%
run_bench(5, 100, 512, 128)
# Out:
# 0 :
#   0%|          | 0/100 [00:00<?, ?it/s]
# 81.29359841346741
# 1 :
#   0%|          | 0/100 [00:00<?, ?it/s]
# 80.37861514091492
# 2 :
#   0%|          | 0/100 [00:00<?, ?it/s]
# 80.15967798233032
# 3 :
#   0%|          | 0/100 [00:00<?, ?it/s]
# 80.07884001731873
# 4 :
#   0%|          | 0/100 [00:00<?, ?it/s]
# 80.34240293502808
# 5 :
#   0%|          | 0/100 [00:00<?, ?it/s]
# 79.97054433822632
# Mean: 80.18601608276367 Std. Dev.: 0.15502239966829467

# %%
run_bench(5, 100, 512, 256)
# Out:
# 0 :
#   0%|          | 0/100 [00:00<?, ?it/s]
# 64.72566843032837
# 1 :
#   0%|          | 0/100 [00:00<?, ?it/s]
# 64.08358216285706
# 2 :
#   0%|          | 0/100 [00:00<?, ?it/s]
# 64.47463417053223
# 3 :
#   0%|          | 0/100 [00:00<?, ?it/s]
# 63.99449133872986
# 4 :
#   0%|          | 0/100 [00:00<?, ?it/s]
# 63.921780586242676
# 5 :
#   0%|          | 0/100 [00:00<?, ?it/s]
# 63.9120135307312
# Mean: 64.0773003578186 Std. Dev.: 0.2079793682085679

# %%
metrics

# %%
acc, loss, preds, tgts = test_gd(SNN, grad_params, (x_test,y_test))
print("Accuracy:", acc, "Loss:", loss)

# %% [markdown]
# ### Use NIR to save our network and then load it up later, in any framework of our choosing!

# %%
import nir

export_params = spyx.nir.reorder_layers(params, grad_params)
G = spyx.nir.to_nir(export_params, obs_shape, act_shape, 1)
nir.write("./spyx_shd.nir", G)
